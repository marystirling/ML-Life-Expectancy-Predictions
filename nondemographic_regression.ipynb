# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold
from sklearn.feature_selection import mutual_info_regression
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score
import scipy as sc
import pickle
from sklearn.preprocessing import PolynomialFeatures
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline
from sklearn.svm import SVR
import seaborn as sns

# %% [markdown]
# # PCA

# %%
# importing dataset
with open('EJSLE_mnmdstdv_demoend.pkl', 'rb') as file:
    df = pickle.load(file)

file.close()

y_mean = df['LE_MEAN']
y_median = df['LE_MEDI']

# Selecting X variables by excluding unwanted columns
# exclusing STATE_NAME, ST_ABBREV, CITY_NAME, LE_MEAN, LE_MEDI
X = df.drop(['LE_MEAN', 'LE_MEDI'], axis=1)
X = X.drop(X.columns[:3], axis=1)

# excluding all demographic columns 
X= X.loc[:, :'P_PWDIS_D2_STDV']

# %%
# Normalizing the data to mean = 0 and variance = 1
def normalization(X):
    mean = np.mean(X, axis=0)
    std = np.std(X, axis=0)
    X = (X - mean) / std
    return X

X = normalization(X)

# Apply PCA to the training data to get 95% variance
pca = PCA(n_components=0.95)
X_pca = pca.fit_transform(X)
print(f"To achieve 95% variance: {pca.n_components_} components are needed")
# Out:
# To achieve 95% variance: 39 components are needed

# %%
# To keep track of best performance of PCA
best_mse = 10000
best_type = ""

# %% [markdown]
# #### Linear Regression

# %%
targets = [y_mean, y_median]
target_names = ["Life expectancy mean", "Life expectancy median"]
colors = ['blue', 'red']
for i, target in enumerate(targets):
    # create copy of these to keep indexing correct in kfold cv below
    X_copy = X_pca.copy()
    y_copy = target.copy().to_numpy().reshape(-1, 1)

    mse_mean = []

    # perform k_folds for k = 3, 5, 10
    #k_folds = [3, 5, 10]
    k_folds = [5]
    for k in k_folds:
        scores = [] 
        rmse_list = [] 
        mse_list = []
        lrmodel = LinearRegression()
        cv = KFold(n_splits=k, shuffle=True)
        for train_index, test_index in cv.split(X_copy):
            X_train, X_test = X_copy[train_index], X_copy[test_index]
            y_train_fold, y_test_fold = y_copy[train_index], y_copy[test_index] # use y_train_copy
            lrmodel.fit(X_train, y_train_fold)
            y_predict = lrmodel.predict(X_test)
            scores.append(r2_score(y_test_fold, y_predict))
            rmse_list.append(np.sqrt(mean_squared_error(y_test_fold, y_predict)))
            mse_list.append(mean_squared_error(y_test_fold, y_predict))
        mse_mean.append(np.mean(mse_list))
        print(f"Mean scores for k = {k} for target {target_names[i]}:")
        print(f"\tR2: {np.mean(scores)}")
        print(f"\tRMSE: {np.mean(rmse_list)}")
        print(f"\tMSE: {np.mean(mse_list)}")
        print()
        if np.mean(mse_list) < best_mse:
            best_mse = np.mean(mse_list)
            best_type = f"linear regression for the target {target_names[i]}"
print(best_mse, best_type)
# Out:
# Mean scores for k = 5 for target Life expectancy mean:
# 	R2: 0.40917001643379686
# 	RMSE: 1.7140124366817677
# 	MSE: 2.9420378701307905
#
# Mean scores for k = 5 for target Life expectancy median:
# 	R2: 0.402665159683706
# 	RMSE: 1.7377277972249174
# 	MSE: 3.0235714740802404
#
# 2.9420378701307905 linear regression for the target Life expectancy mean

# %% [markdown]
# #### Polynomial Regression

# %%
'''targets = [y_mean, y_median]
target_names = ["Life expectancy mean", "Life expectancy median"]
colors = ['blue', 'red']
# perform k_folds for k = 3, 5, 10
#k_folds = [3, 5, 10]
k = [5]
# perform for degrees 2, 3, 4
degrees = [2, 3, 4]
bar_width = 0.35
bar_positions = np.arange(len(degrees))

fig, ax = plt.subplots()
for idx, target in enumerate(targets):
    # create copy of these to keep indexing correct in kfold cv below
    X_copy = X_pca.copy()
    y_copy = target.copy().to_numpy()

    mse_mean = []


    
    for k in k_folds:
        #mse_mean = []
        for d in degrees:

            scores = [] # to store r squared
            rmse_list = [] # to store RMSE
            mse_list = [] # to store MSE
            degree = d
            cv = KFold(n_splits=k, shuffle=True)
            for train_index, test_index in cv.split(X_copy):
                X_train, X_test = X_copy[train_index], X_copy[test_index]
                y_train_fold, y_test_fold = y_copy[train_index], y_copy[test_index] # use y_train_copy

                model = make_pipeline(PolynomialFeatures(degree), LinearRegression())
                model.fit(X_train, y_train_fold)

                y_predict = model.predict(X_test)
                scores.append(r2_score(y_test_fold, y_predict))
                rmse_list.append(np.sqrt(mean_squared_error(y_test_fold, y_predict)))
                mse_list.append(mean_squared_error(y_test_fold, y_predict))
        mse_mean.append(np.mean(mse_list))
        print(f"Mean scores for k = {k}, degree = {d} and for target {target_names[idx]}:")
        print(f"\tR2: {np.mean(scores)}")
        print(f"\tRMSE: {np.mean(rmse_list)}")
        print(f"\tMSE: {np.mean(mse_list)}")
        print()
        if np.mean(mse_list) < best_mse:
            best_mse = np.mean(mse_list)
            best_type = f"Polynomial regression with degree = {d} for the target {target_names[idx]}"

    # plot the bar for this target
    ax.bar(bar_positions + idx * bar_width, mse_mean, width=bar_width, color=colors[idx], label=target_names[idx])

# set labels, title and legend
ax.set_xlabel('Degree of Polynomial')
ax.set_ylabel('Mean Squared Error (MSE)')
ax.set_title('MSE for Polynomial Regression with PCA')
ax.set_xticks(bar_positions + bar_width / 2)
ax.set_xticklabels(degrees)
ax.legend()

plt.show()'''
# Out:
# 'targets = [y_mean, y_median]\ntarget_names = ["Life expectancy mean", "Life expectancy median"]\ncolors = [\'blue\', \'red\']\n# perform k_folds for k = 3, 5, 10\n#k_folds = [3, 5, 10]\nk = [5]\n# perform for degrees 2, 3, 4\ndegrees = [2, 3, 4]\nbar_width = 0.35\nbar_positions = np.arange(len(degrees))\n\nfig, ax = plt.subplots()\nfor idx, target in enumerate(targets):\n    # create copy of these to keep indexing correct in kfold cv below\n    X_copy = X_pca.copy()\n    y_copy = target.copy().to_numpy()\n\n    mse_mean = []\n\n\n    \n    for k in k_folds:\n        #mse_mean = []\n        for d in degrees:\n\n            scores = [] # to store r squared\n            rmse_list = [] # to store RMSE\n            mse_list = [] # to store MSE\n            degree = d\n            cv = KFold(n_splits=k, shuffle=True)\n            for train_index, test_index in cv.split(X_copy):\n                X_train, X_test = X_copy[train_index], X_copy[test_index]\n                y_train_fold, y_test_fold = y_copy[train_index], y_copy[test_index] # use y_train_copy\n\n                model = make_pipeline(PolynomialFeatures(degree), LinearRegression())\n                model.fit(X_train, y_train_fold)\n\n                y_predict = model.predict(X_test)\n                scores.append(r2_score(y_test_fold, y_predict))\n                rmse_list.append(np.sqrt(mean_squared_error(y_test_fold, y_predict)))\n                mse_list.append(mean_squared_error(y_test_fold, y_predict))\n        mse_mean.append(np.mean(mse_list))\n        print(f"Mean scores for k = {k}, degree = {d} and for target {target_names[idx]}:")\n        print(f"\tR2: {np.mean(scores)}")\n        print(f"\tRMSE: {np.mean(rmse_list)}")\n        print(f"\tMSE: {np.mean(mse_list)}")\n        print()\n        if np.mean(mse_list) < best_mse:\n            best_mse = np.mean(mse_list)\n            best_type = f"Polynomial regression with degree = {d} for the target {target_names[idx]}"\n\n    # plot the bar for this target\n    ax.bar(bar_positions + idx * bar_width, mse_mean, width=bar_width, color=colors[idx], label=target_names[idx])\n\n# set labels, title and legend\nax.set_xlabel(\'Degree of Polynomial\')\nax.set_ylabel(\'Mean Squared Error (MSE)\')\nax.set_title(\'MSE for Polynomial Regression with PCA\')\nax.set_xticks(bar_positions + bar_width / 2)\nax.set_xticklabels(degrees)\nax.legend()\n\nplt.show()'

# %% [markdown]
# #### Locally-weighted regression

# %%
def local_regression(xi, X, y, tau):
    m = X.shape[0]
    W = np.zeros((m,m))
    # fill in the weight matrix
    for i in range(m):
        xit = np.concatenate(([1], X[i, :]))  # add a 1 to the beginning of xit
        xi_ = np.concatenate(([1], xi[0, :]))  # add a 1 to the beginning of xi
        W[i, i] = np.exp(-np.dot((xi_ - xit), (xi_ - xit).T) / (2 * tau * tau))
    W += 1e-8 * np.identity(m)  # add a small constant to the diagonal to avoid zero weights
    W = W / np.sum(W, axis=0)  # normalize the weights
    lrmodel = LinearRegression()
    lrmodel.fit(X, y, sample_weight=W.diagonal())
    return lrmodel.predict(xi.reshape(1, -1))



targets = [y_mean, y_median]
target_names = ["Life expectancy mean", "Life expectancy median"]
colors = ['blue', 'red']

# perform k_folds for k = 3, 5, 10
#k_folds = [3, 5, 10]
k_folds = [5]
# define a list of bandwidths to try
tau_list = [0.01, 0.05, 0.1, 0.5, 1, 5, 10]
bar_width = 0.35
bar_positions = np.arange(len(tau_list))
fig, ax = plt.subplots()
for idx, target in enumerate(targets):
    # create copy of these to keep indexing correct in kfold cv below
    X_copy = X_pca.copy()
    y_copy = target.copy().to_numpy().reshape(-1, 1)

    mse_mean = []


    for k in k_folds:
        for tau in tau_list:
            scores = [] # to store r squared
            rmse_list = [] # to store RMSE
            mse_list = []

            kf = KFold(n_splits=k, shuffle=True)
            for train_index, test_index in kf.split(X_copy):
                X_train_fold, X_test_fold = X_copy[train_index], X_copy[test_index]
                y_train_fold, y_test_fold = y_copy[train_index], y_copy[test_index]

                # Create a copy of y_train_fold
                y_train_fold_copy = y_train_fold.copy()

                y_pred_fold = np.zeros(len(X_test_fold))
                for i in range(len(X_test_fold)):
                    y_pred_fold[i] = local_regression(X_test_fold[i].reshape(1,-1), X_train_fold, y_train_fold_copy, tau)

                scores.append(r2_score(y_test_fold, y_pred_fold))
                rmse_list.append(np.sqrt(mean_squared_error(y_test_fold, y_pred_fold)))
                mse_list.append(mean_squared_error(y_test_fold, y_pred_fold))
            mse_mean.append(np.mean(mse_list))

            print(f"Mean scores for k = {k} and tau = {tau}:")
            print(f"\tR2: {np.mean(scores)}")
            print(f"\tRMSE: {np.mean(rmse_list)}")
            print(f"\tMSE: {np.mean(mse_list)}")
            print()
            print(rmse_list)
            print()
            if np.mean(mse_list) < best_mse:
                best_mse = np.mean(mse_list)
                best_type = f"Locally-weighted regression with tau = {tau} for the target {target_names[idx]}"
        # plot the bar for this target
    ax.bar(bar_positions + idx * bar_width, mse_mean, width=bar_width, color=colors[idx], label=target_names[idx])

# set labels, title and legend
ax.set_xlabel('Tau')
ax.set_ylabel('Mean Squared Error (MSE)')
ax.set_title('MSE for Locally-Weighted Regression with PCA')
ax.set_xticks(bar_positions + bar_width / 2)
ax.set_xticklabels(tau_list)
ax.legend()
ax.set_ylim([2.7, 3.1])
plt.show()
print(best_mse, best_type)
# Out:
# Mean scores for k = 5 and tau = 0.01:
# 	R2: 0.4149683166077245
# 	RMSE: 1.7082096535069926
# 	MSE: 2.922440458341981
#
# [1.7302296922718299, 1.596124071967272, 1.7689162540427867, 1.6722094183927156, 1.7735688308603585]
#
# Mean scores for k = 5 and tau = 0.05:
# 	R2: 0.4207924660407724
# 	RMSE: 1.6983300003928392
# 	MSE: 2.888468257383336
#
# [1.5835716786517673, 1.7788818895164786, 1.70140831693528, 1.7307062661502968, 1.6970818507103724]
#
# Mean scores for k = 5 and tau = 0.1:
# 	R2: 0.42168991884671597
# 	RMSE: 1.6985779364848792
# 	MSE: 2.8864385394521554
#
# [1.7383489449932708, 1.6611248740170228, 1.7062949119634168, 1.6531667933409295, 1.7339541581097568]
#
# Mean scores for k = 5 and tau = 0.5:
# 	R2: 0.4114328714481661
# 	RMSE: 1.7118876698363241
# 	MSE: 2.9348203168476967
#
# [1.6985490623977404, 1.8017813236364744, 1.7639392161217013, 1.6797296282288856, 1.6154391187968187]
#
# Mean scores for k = 5 and tau = 1:
# 	R2: 0.4167291911779511
# 	RMSE: 1.6998202276955077
# 	MSE: 2.9007426044932916
#
# [1.798113061784234, 1.831444599435827, 1.6404950328409649, 1.5379989396720284, 1.691049504744485]
#
# Mean scores for k = 5 and tau = 5:
# 	R2: 0.4188586861507506
# 	RMSE: 1.7023750277638825
# 	MSE: 2.905792113362733
#
# [1.7277658235775701, 1.5904319451473568, 1.7405651200004684, 1.8332168270624372, 1.619895423031581]
#
# Mean scores for k = 5 and tau = 10:
# 	R2: 0.42432113962948553
# 	RMSE: 1.6966976969592285
# 	MSE: 2.8889109107239346
#
# [1.794681586875755, 1.7844311474386556, 1.754977892165057, 1.584111644670444, 1.5652862136462309]
#
# Mean scores for k = 5 and tau = 0.01:
# 	R2: 0.41538049601035604
# 	RMSE: 1.7208401010218843
# 	MSE: 2.9679520194025457
#
# [1.7406109768414222, 1.7351329462333467, 1.6684260265860649, 1.8520727533224215, 1.6079578021261645]
#
# Mean scores for k = 5 and tau = 0.05:
# 	R2: 0.41306096792241237
# 	RMSE: 1.7207492366150512
# 	MSE: 2.966999213554252
#
# [1.6690284232850456, 1.5940606650948177, 1.8024809997924764, 1.7728291803851184, 1.7653469145177971]
#
# Mean scores for k = 5 and tau = 0.1:
# 	R2: 0.4241571312083736
# 	RMSE: 1.707168754466754
# 	MSE: 2.9237915463128266
#
# [1.7343658226216603, 1.5410189784155595, 1.6954262251862686, 1.723380480483782, 1.841652265626499]
#
# Mean scores for k = 5 and tau = 0.5:
# 	R2: 0.35731353103627655
# 	RMSE: 1.796429597725949
# 	MSE: 3.2472934612559725
#
# [1.6503878528098375, 2.0630634742404816, 1.7882512631584957, 1.7096966697460954, 1.7707487286748347]
#
# Mean scores for k = 5 and tau = 1:
# 	R2: 0.41155142977104536
# 	RMSE: 1.7237764961448374
# 	MSE: 2.9792776321720416
#
# [1.585179237764797, 1.783128561407469, 1.6644269163083036, 1.8349225486703704, 1.7512252165732478]
#
# Mean scores for k = 5 and tau = 5:
# 	R2: 0.39315520964475625
# 	RMSE: 1.7422597478062734
# 	MSE: 3.0413340370893422
#
# [1.7582938221083337, 1.6302087816152133, 1.862926072568164, 1.7586436672806407, 1.7012263954590157]
#
# Mean scores for k = 5 and tau = 10:
# 	R2: 0.4222236452282515
# 	RMSE: 1.7109547611509377
# 	MSE: 2.931783536035611
#
# [1.6955562303854848, 1.8239565114310197, 1.6621298547074401, 1.7390378017029682, 1.6340934075277755]
# 2.8864385394521554 Locally-weighted regression with tau = 0.1 for the target Life expectancy mean

# %% [markdown]
# #### KNN

# %%
targets = [y_mean, y_median]
target_names = ["Life expectancy mean", "Life expectancy median"]
colors = ['blue', 'red']
for idx, target in enumerate(targets):
    # create copy of these to keep indexing correct in kfold cv below
    X_copy = X_pca.copy()
    y_copy = target.copy().to_numpy().reshape(-1, 1)
    # Normalize the data to mean = 0 and variance = 1
    X_train_norm = normalization(X_copy)
    mse_mean = []

    # perform k_folds for k = 3, 5, 10
    #k_folds = [3, 5, 10]
    k = [5]
    # perform for degrees 2, 3, 4, 5
    neighbors = list(range(1, 26))
    for k in k_folds:
        for n in neighbors:
            rmse_list = [] # to store RMSE
            mse_list = []
            knn_model = KNeighborsRegressor(n_neighbors=n)
            cv = KFold(n_splits=5, shuffle=True)
            for train_index, test_index in cv.split(X_train_norm):
                X_train_fold, X_test_fold = X_train_norm[train_index], X_train_norm[test_index]
                y_train_fold, y_test_fold = y_copy[train_index], y_copy[test_index]
                knn_model.fit(X_train_fold, y_train_fold)
                y_predict_norm = knn_model.predict(X_test_fold)
                rmse_list.append(np.sqrt(mean_squared_error(y_test_fold, y_predict_norm)))
                mse_list.append(mean_squared_error(y_test_fold, y_predict_norm))

            mse_mean.append(np.mean(mse_list))

            print(f"Mean scores for k = {k} and neighbors = {n} for {target_names[idx]}:")
            print(f"\tR2: {np.mean(scores)}")
            print(f"\tRMSE: {np.mean(rmse_list)}")
            print(f"\tMSE: {np.mean(mse_list)}")
            print()
            print(rmse_list)
            print()
            if np.mean(mse_list) < best_mse:
                best_mse = np.mean(mse_list)
                best_type = f"KNN with neighbors = {n} for the target {target_names[idx]}"
    plt.plot(neighbors, mse_mean, color=colors[idx], label=target_names[idx])
    
plt.xlabel("# of K-Neighbors")
plt.ylabel("Mean Squared Error (MSE)")
plt.xticks(range(len(neighbors)), [str(n) for n in neighbors])
plt.title("MSE for K-Nearest Neighbors with PCA")
plt.legend()
plt.show()
print(best_mse, best_type)
# Out:
# Mean scores for k = 5 and neighbors = 1 for Life expectancy mean:
# 	R2: 0.4222236452282515
# 	RMSE: 2.122299552073632
# 	MSE: 4.504925622134612
#
# [2.1403070036270564, 2.0711372209844656, 2.1496583488867365, 2.133683273399456, 2.116711913470445]
#
# Mean scores for k = 5 and neighbors = 2 for Life expectancy mean:
# 	R2: 0.4222236452282515
# 	RMSE: 1.8846041751960336
# 	MSE: 3.553742164146893
#
# [1.887768495706255, 1.9038201452983496, 1.9490858404146398, 1.811705557089739, 1.870640837471185]
#
# Mean scores for k = 5 and neighbors = 3 for Life expectancy mean:
# 	R2: 0.4222236452282515
# 	RMSE: 1.79576584679191
# 	MSE: 3.2403944897933825
#
# [1.7293466530100885, 1.8418582209326477, 1.633504310055069, 1.767553770034885, 2.00656627992686]
#
# Mean scores for k = 5 and neighbors = 4 for Life expectancy mean:
# 	R2: 0.4222236452282515
# 	RMSE: 1.7614375409526655
# 	MSE: 3.104786961666689
#
# [1.704422039213856, 1.8112386342786087, 1.720922924814195, 1.8178010885865687, 1.752803017870099]
#
# Mean scores for k = 5 and neighbors = 5 for Life expectancy mean:
# 	R2: 0.4222236452282515
# 	RMSE: 1.7717133702084642
# 	MSE: 3.141003151275833
#
# [1.8407547044468042, 1.7161324797024375, 1.731064895802874, 1.7731297153720174, 1.7974850557181878]
#
# Mean scores for k = 5 and neighbors = 6 for Life expectancy mean:
# 	R2: 0.4222236452282515
# 	RMSE: 1.7492943964082837
# 	MSE: 3.061304535393984
#
# [1.7332917983102956, 1.797309433215464, 1.7243255066762229, 1.7060330176704344, 1.7855122261690022]
#
# Mean scores for k = 5 and neighbors = 7 for Life expectancy mean:
# 	R2: 0.4222236452282515
# 	RMSE: 1.7648810882173507
# 	MSE: 3.1193586392405583
#
# [1.7388784205320378, 1.659402906133251, 1.853376504143641, 1.8196139949899168, 1.753133615287907]
#
# Mean scores for k = 5 and neighbors = 8 for Life expectancy mean:
# 	R2: 0.4222236452282515
# 	RMSE: 1.7581298911846297
# 	MSE: 3.0950689709853156
#
# [1.7685429409760969, 1.7334037703828733, 1.6506090811537668, 1.8354632718165356, 1.802630391593876]
#
# Mean scores for k = 5 and neighbors = 9 for Life expectancy mean:
# 	R2: 0.4222236452282515
# 	RMSE: 1.7362878778489308
# 	MSE: 3.026323399148076
#
# [1.63122944766515, 1.894892042269231, 1.6365021771686465, 1.6855153246347745, 1.8333003975068525]
#
# Mean scores for k = 5 and neighbors = 10 for Life expectancy mean:
# 	R2: 0.4222236452282515
# 	RMSE: 1.7437093268009192
# 	MSE: 3.0433246660883553
#
# [1.7379128160933468, 1.832233616215257, 1.7665133353775468, 1.696120177103295, 1.6857666892151508]
#
# Mean scores for k = 5 and neighbors = 11 for Life expectancy mean:
# 	R2: 0.4222236452282515
# 	RMSE: 1.7510600739948121
# 	MSE: 3.0691695932878162
#
# [1.7987322035254627, 1.7051728268110737, 1.6771537358054762, 1.8213982167575677, 1.75284338707448]
#
# Mean scores for k = 5 and neighbors = 12 for Life expectancy mean:
# 	R2: 0.4222236452282515
# 	RMSE: 1.7441174062318368
# 	MSE: 3.0428036781457246
#
# [1.7839898202054736, 1.7076408996518142, 1.7352347002848316, 1.7721239926766654, 1.7215976183403983]
#
# Mean scores for k = 5 and neighbors = 13 for Life expectancy mean:
# 	R2: 0.4222236452282515
# 	RMSE: 1.7364725785680826
# 	MSE: 3.016440053812429
#
# [1.6849872047702472, 1.7760237373736818, 1.716159823868109, 1.7661535163292148, 1.7390386104991589]
#
# Mean scores for k = 5 and neighbors = 14 for Life expectancy mean:
# 	R2: 0.4222236452282515
# 	RMSE: 1.7421955199016061
# 	MSE: 3.040097164601211
#
# [1.8355212244782324, 1.7441693236913032, 1.6650181676794737, 1.6644848162802244, 1.8017840673787973]
#
# Mean scores for k = 5 and neighbors = 15 for Life expectancy mean:
# 	R2: 0.4222236452282515
# 	RMSE: 1.7473543960970825
# 	MSE: 3.066779848261722
#
# [1.7843624354359962, 1.816315397572517, 1.5332212001748695, 1.871558977130452, 1.731313970171578]
#
# Mean scores for k = 5 and neighbors = 16 for Life expectancy mean:
# 	R2: 0.4222236452282515
# 	RMSE: 1.7582248479205074
# 	MSE: 3.095241137553038
#
# [1.8392850618984533, 1.7685470575379405, 1.778640602803762, 1.7575031219526127, 1.647148395409769]
#
# Mean scores for k = 5 and neighbors = 17 for Life expectancy mean:
# 	R2: 0.4222236452282515
# 	RMSE: 1.7559523506167334
# 	MSE: 3.0847878952641534
#
# [1.8121928254311819, 1.7543816942505823, 1.7673561318877298, 1.6944741755035573, 1.751356926010616]
#
# Mean scores for k = 5 and neighbors = 18 for Life expectancy mean:
# 	R2: 0.4222236452282515
# 	RMSE: 1.7543501374479562
# 	MSE: 3.085737738510539
#
# [1.624586892552845, 1.8749873809780884, 1.7413983909700157, 1.8292770512140981, 1.701500971524732]
#
# Mean scores for k = 5 and neighbors = 19 for Life expectancy mean:
# 	R2: 0.4222236452282515
# 	RMSE: 1.7568638804813212
# 	MSE: 3.1006503824988982
#
# [1.8588340708302165, 1.8810198621509033, 1.6448903492234996, 1.5868001097087598, 1.8127750104932256]
#
# Mean scores for k = 5 and neighbors = 20 for Life expectancy mean:
# 	R2: 0.4222236452282515
# 	RMSE: 1.758323341344622
# 	MSE: 3.10332501573341
#
# [1.9132074077103638, 1.8378499943074516, 1.7220109412469677, 1.7178685077902405, 1.600679855668086]
#
# Mean scores for k = 5 and neighbors = 21 for Life expectancy mean:
# 	R2: 0.4222236452282515
# 	RMSE: 1.7834601645699197
# 	MSE: 3.187996229724859
#
# [1.6345357357012575, 1.8191200318359333, 1.794153377153211, 1.7734863160525531, 1.8960053621066446]
#
# Mean scores for k = 5 and neighbors = 22 for Life expectancy mean:
# 	R2: 0.4222236452282515
# 	RMSE: 1.7762859819377965
# 	MSE: 3.1623389223820952
#
# [1.7318097358155506, 1.6875446761075592, 1.8841114331681457, 1.705515570127774, 1.8724484944699529]
#
# Mean scores for k = 5 and neighbors = 23 for Life expectancy mean:
# 	R2: 0.4222236452282515
# 	RMSE: 1.7822200854939851
# 	MSE: 3.179070196320705
#
# [1.8695990871547947, 1.7554649216345337, 1.811604683984633, 1.720728398502195, 1.7537033361937682]
#
# Mean scores for k = 5 and neighbors = 24 for Life expectancy mean:
# 	R2: 0.4222236452282515
# 	RMSE: 1.7819748455104467
# 	MSE: 3.179398081040776
#
# [1.8122274872603088, 1.8763606252341456, 1.6863174771446752, 1.7820526828798082, 1.7529159550332956]
#
# Mean scores for k = 5 and neighbors = 25 for Life expectancy mean:
# 	R2: 0.4222236452282515
# 	RMSE: 1.7864167397478048
# 	MSE: 3.1973162989397723
#
# [1.7676547536718665, 1.7245341355004158, 1.7985758706373587, 1.9290181610221855, 1.7123007779071995]
#
# Mean scores for k = 5 and neighbors = 1 for Life expectancy median:
# 	R2: 0.4222236452282515
# 	RMSE: 2.155166675430965
# 	MSE: 4.6549485825663
#
# [2.188658615960202, 2.0469252337643784, 2.3160426157690304, 2.046536510378373, 2.1776704012828425]
#
# Mean scores for k = 5 and neighbors = 2 for Life expectancy median:
# 	R2: 0.4222236452282515
# 	RMSE: 1.8568823856549337
# 	MSE: 3.4493614482200643
#
# [1.897287708084672, 1.898612378660082, 1.8561223368759505, 1.8217057975938404, 1.8106837070601227]
#
# Mean scores for k = 5 and neighbors = 3 for Life expectancy median:
# 	R2: 0.4222236452282515
# 	RMSE: 1.8268215571204576
# 	MSE: 3.3441501743043007
#
# [1.8078343432365154, 1.7533534931019312, 1.7299955935451754, 1.9471412704229052, 1.8957830852957593]
#
# Mean scores for k = 5 and neighbors = 4 for Life expectancy median:
# 	R2: 0.4222236452282515
# 	RMSE: 1.778471779237806
# 	MSE: 3.1698762139205856
#
# [1.775099135752021, 1.8618793898798989, 1.62896516478733, 1.8508781151329017, 1.7755370906368797]
#
# Mean scores for k = 5 and neighbors = 5 for Life expectancy median:
# 	R2: 0.4222236452282515
# 	RMSE: 1.7927729850677099
# 	MSE: 3.2177812919766318
#
# [1.8676539806896142, 1.796818565667887, 1.6940549006665904, 1.8424615627984242, 1.7628759155160334]
#
# Mean scores for k = 5 and neighbors = 6 for Life expectancy median:
# 	R2: 0.4222236452282515
# 	RMSE: 1.764814787945293
# 	MSE: 3.1194797838241413
#
# [1.7064201142323483, 1.8823271075468864, 1.6857852335483805, 1.75379760850199, 1.7957438758968585]
#
# Mean scores for k = 5 and neighbors = 7 for Life expectancy median:
# 	R2: 0.4222236452282515
# 	RMSE: 1.7747876534877267
# 	MSE: 3.1516053502916734
#
# [1.8160524122879105, 1.7247314285880933, 1.7410896694043119, 1.8308464548003092, 1.7612183023580088]
#
# Mean scores for k = 5 and neighbors = 8 for Life expectancy median:
# 	R2: 0.4222236452282515
# 	RMSE: 1.780834064526065
# 	MSE: 3.1748607981634556
#
# [1.7838602560250874, 1.7668148055296664, 1.8689153226435842, 1.6851985343100033, 1.7993814041219838]
#
# Mean scores for k = 5 and neighbors = 9 for Life expectancy median:
# 	R2: 0.4222236452282515
# 	RMSE: 1.7620345943140319
# 	MSE: 3.113687566384032
#
# [1.7757052599355023, 1.7803067682454858, 1.639559708883689, 1.9190802921892474, 1.695520942316235]
#
# Mean scores for k = 5 and neighbors = 10 for Life expectancy median:
# 	R2: 0.4222236452282515
# 	RMSE: 1.7522383818833789
# 	MSE: 3.071368826335477
#
# [1.710927425030554, 1.725046948378517, 1.775640114306382, 1.7986293482726035, 1.7509480734288372]
#
# Mean scores for k = 5 and neighbors = 11 for Life expectancy median:
# 	R2: 0.4222236452282515
# 	RMSE: 1.751272694452376
# 	MSE: 3.068861417458014
#
# [1.7268996283376363, 1.7971826288913166, 1.7987155559400796, 1.6836532316239083, 1.74991242746894]
#
# Mean scores for k = 5 and neighbors = 12 for Life expectancy median:
# 	R2: 0.4222236452282515
# 	RMSE: 1.7688419721724447
# 	MSE: 3.142522292424067
#
# [1.8772346296663112, 1.8251600504658791, 1.5743051525712675, 1.6960287820669682, 1.8714812460917973]
#
# Mean scores for k = 5 and neighbors = 13 for Life expectancy median:
# 	R2: 0.4222236452282515
# 	RMSE: 1.7599468900740463
# 	MSE: 3.1006068934488478
#
# [1.7021696206422643, 1.8488904132820598, 1.7208623611557072, 1.8036620002320916, 1.7241500550581081]
#
# Mean scores for k = 5 and neighbors = 14 for Life expectancy median:
# 	R2: 0.4222236452282515
# 	RMSE: 1.760898940989032
# 	MSE: 3.1050822533070104
#
# [1.716858838071228, 1.7565742373488282, 1.8155139639704345, 1.848947561419578, 1.6666001041350924]
#
# Mean scores for k = 5 and neighbors = 15 for Life expectancy median:
# 	R2: 0.4222236452282515
# 	RMSE: 1.7754007864220747
# 	MSE: 3.155555030354399
#
# [1.7944181902488237, 1.7518889994867919, 1.7342790341893157, 1.8815440490878788, 1.7148736590975626]
#
# Mean scores for k = 5 and neighbors = 16 for Life expectancy median:
# 	R2: 0.4222236452282515
# 	RMSE: 1.7704439713760398
# 	MSE: 3.139015433180355
#
# [1.7981801050451034, 1.7478670398276455, 1.8654071877969123, 1.7812457813518061, 1.6595197428587305]
#
# Mean scores for k = 5 and neighbors = 17 for Life expectancy median:
# 	R2: 0.4222236452282515
# 	RMSE: 1.7765539711761114
# 	MSE: 3.1598790958442455
#
# [1.8755446982817838, 1.7854485453526276, 1.7572604850996287, 1.6848204954190307, 1.7796956317274863]
#
# Mean scores for k = 5 and neighbors = 18 for Life expectancy median:
# 	R2: 0.4222236452282515
# 	RMSE: 1.7783912285438241
# 	MSE: 3.168520920667091
#
# [1.8710848292398905, 1.8408975993773213, 1.7012871881043978, 1.677157556264334, 1.8015289697331762]
#
# Mean scores for k = 5 and neighbors = 19 for Life expectancy median:
# 	R2: 0.4222236452282515
# 	RMSE: 1.7930008596360831
# 	MSE: 3.217344141538522
#
# [1.717423661901802, 1.773637281053853, 1.7788793616101553, 1.8581792234931425, 1.8368847701214632]
#
# Mean scores for k = 5 and neighbors = 20 for Life expectancy median:
# 	R2: 0.4222236452282515
# 	RMSE: 1.7920008872532134
# 	MSE: 3.2121736528075475
#
# [1.7654257144027417, 1.7649854460010344, 1.7723760460764246, 1.8325395652255048, 1.8246776645603613]
#
# Mean scores for k = 5 and neighbors = 21 for Life expectancy median:
# 	R2: 0.4222236452282515
# 	RMSE: 1.7843606880380416
# 	MSE: 3.1967338785498094
#
# [1.728397699279066, 1.9401705950211765, 1.6063571705522866, 1.7933889859652035, 1.853488989372476]
#
# Mean scores for k = 5 and neighbors = 22 for Life expectancy median:
# 	R2: 0.4222236452282515
# 	RMSE: 1.7925129007104932
# 	MSE: 3.2223800644713547
#
# [1.6504555534134686, 1.924676886677244, 1.7760469931043326, 1.7419677929719712, 1.8694172773854496]
#
# Mean scores for k = 5 and neighbors = 23 for Life expectancy median:
# 	R2: 0.4222236452282515
# 	RMSE: 1.7980511639610406
# 	MSE: 3.2343622044521196
#
# [1.745119195738527, 1.8211808201593438, 1.8451805360851603, 1.813502107510076, 1.7652731603120948]
#
# Mean scores for k = 5 and neighbors = 24 for Life expectancy median:
# 	R2: 0.4222236452282515
# 	RMSE: 1.803022690582143
# 	MSE: 3.2519597626534074
#
# [1.7999736280542942, 1.7899487786376822, 1.8633927024605534, 1.797346619204598, 1.764451724553586]
#
# Mean scores for k = 5 and neighbors = 25 for Life expectancy median:
# 	R2: 0.4222236452282515
# 	RMSE: 1.810743090766061
# 	MSE: 3.284466995292732
#
# [1.839217031246147, 1.6881019731771711, 1.9106291344267694, 1.7722670235033438, 1.843500291476875]
# 2.8864385394521554 Locally-weighted regression with tau = 0.1 for the target Life expectancy mean

# %% [markdown]
# #### SVR

# %%
targets = [y_mean, y_median]
target_names = ["Life expectancy mean", "Life expectancy median"]
colors = ['blue', 'red']
# perform for different kernels
kernel = ['linear', 'poly', 'rbf', 'sigmoid']
bar_width = 0.35
bar_positions = np.arange(len(kernel))

fig, ax = plt.subplots()
for idx, target in enumerate(targets):
    # create copy of these to keep indexing correct in kfold cv below
    X_copy = X_pca.copy()
    y_copy = target.copy().to_numpy().reshape(-1,)
    # Normalize the data to mean = 0 and variance = 1
    X_train_norm = normalization(X_copy)
    mse_mean = []



    # perform k_folds for k = 3, 5, 10
    #k_folds = [3, 5, 10]
    k = [5]
  
    for k in k_folds:
        for ker in kernel:
            rmse_list = [] # to store RMSE
            mse_list = []
            svr_model = SVR(kernel=ker)
            cv = KFold(n_splits=k, shuffle=True)
            for train_index, test_index in cv.split(X_train_norm):
                X_train_fold, X_test_fold = X_train_norm[train_index], X_train_norm[test_index]
                y_train_fold, y_test_fold = y_copy[train_index], y_copy[test_index]
                svr_model.fit(X_train_fold, y_train_fold)
                y_predict_norm = svr_model.predict(X_test_fold)
                rmse_list.append(np.sqrt(mean_squared_error(y_test_fold, y_predict_norm)))
                mse_list.append(mean_squared_error(y_test_fold, y_predict_norm))

            mse_mean.append(np.mean(mse_list))

            print(f"Mean scores for k = {k} and kernel = {kernel} for {target_names[idx]}:")
            print(f"\tR2: {np.mean(scores)}")
            print(f"\tRMSE: {np.mean(rmse_list)}")
            print(f"\tMSE: {np.mean(mse_list)}")
            print()
            print(rmse_list)
            print()
            if np.mean(mse_list) < best_mse:
                best_mse = np.mean(mse_list)
                best_type = f"SVR with kernel = {ker} for the target {target_names[idx]}"
    # plot the bar for this target
    ax.bar(bar_positions + idx * bar_width, mse_mean, width=bar_width, color=colors[idx], label=target_names[idx])

# set labels, title and legend
ax.set_xlabel('Kernel')
ax.set_ylabel('Mean Squared Error (MSE)')
ax.set_title('MSE for Support Vector Regression with PCA')
ax.set_xticks(bar_positions + bar_width / 2)
ax.set_xticklabels(kernel)
ax.legend()

plt.show()
print(best_mse, best_type)
# Out:
# Mean scores for k = 5 and kernel = ['linear', 'poly', 'rbf', 'sigmoid'] for Life expectancy mean:
# 	R2: 0.4222236452282515
# 	RMSE: 1.7063387346500325
# 	MSE: 2.91717932403102
#
# [1.650660264585077, 1.8302873350307505, 1.662166824391242, 1.7544243317121881, 1.6341549175309038]
#
# Mean scores for k = 5 and kernel = ['linear', 'poly', 'rbf', 'sigmoid'] for Life expectancy mean:
# 	R2: 0.4222236452282515
# 	RMSE: 2.0719340829456874
# 	MSE: 4.4182588599843395
#
# [1.8042151080672153, 1.7038494892950196, 1.9617014881577992, 2.190841796332126, 2.699062532876277]
#
# Mean scores for k = 5 and kernel = ['linear', 'poly', 'rbf', 'sigmoid'] for Life expectancy mean:
# 	R2: 0.4222236452282515
# 	RMSE: 1.6066133397457594
# 	MSE: 2.5897968749318743
#
# [1.6937864457333398, 1.6733908669116828, 1.5805298855252785, 1.4377071001171202, 1.6476524004413762]
#
# Mean scores for k = 5 and kernel = ['linear', 'poly', 'rbf', 'sigmoid'] for Life expectancy mean:
# 	R2: 0.4222236452282515
# 	RMSE: 2.075984914697982
# 	MSE: 4.358763352050691
#
# [2.4461100889546836, 2.0260228082298286, 2.1705573095814223, 1.7950835740008224, 1.9421507927231536]
#
# Mean scores for k = 5 and kernel = ['linear', 'poly', 'rbf', 'sigmoid'] for Life expectancy median:
# 	R2: 0.4222236452282515
# 	RMSE: 1.74475112310965
# 	MSE: 3.0475099956125726
#
# [1.6724917417280332, 1.8211687648159283, 1.6876776489142882, 1.7483056237806072, 1.7941118363093926]
#
# Mean scores for k = 5 and kernel = ['linear', 'poly', 'rbf', 'sigmoid'] for Life expectancy median:
# 	R2: 0.4222236452282515
# 	RMSE: 2.0101193845075036
# 	MSE: 4.08446504397713
#
# [2.1334404057744987, 1.9097249452299838, 2.328807472276996, 1.9701287414412356, 1.708495357814802]
#
# Mean scores for k = 5 and kernel = ['linear', 'poly', 'rbf', 'sigmoid'] for Life expectancy median:
# 	R2: 0.4222236452282515
# 	RMSE: 1.6131367892507362
# 	MSE: 2.608877347300328
#
# [1.6078122973078808, 1.5171678401498876, 1.7633595670276008, 1.5757701837190254, 1.6015740580492872]
#
# Mean scores for k = 5 and kernel = ['linear', 'poly', 'rbf', 'sigmoid'] for Life expectancy median:
# 	R2: 0.4222236452282515
# 	RMSE: 2.190741505960973
# 	MSE: 4.8423435871464
#
# [2.0549014220489137, 2.565659929281769, 1.9567013282508332, 2.212433550337515, 2.164011299885836]
# 2.5897968749318743 SVR with kernel = rbf for the target Life expectancy mean

# %%
print("For PCA, the lowest MSE value with kfold cv of k = 5 is:")
print(f"\t {best_type}")
print(f"\t MSE = {best_mse}")
# Out:
# For PCA, the lowest MSE value with kfold cv of k = 5 is:
# 	 SVR with kernel = rbf for the target Life expectancy mean
# 	 MSE = 2.5897968749318743

# %% [markdown]
# # Filter Method

# %%
'''
Filter method to perform feature selection
@param X - data inputs (pandas Dataframe)
       y - data targets (pandas DataFrame)
       threshold - correlation value to be above to be selected as feature
       feature_type - either "MEAN" or "MEDI" to indicate what type of features to include
@return features - selected features (list)
'''
def Filter(X, y, threshold, feature_type, num_features):
    # filter feature names to only include those that contain "MEAN" or "MEDI"
    #names = [col for col in X.columns if feature_type in col]
    names = [col for col in X.columns]
    X_filtered = X[names]
    

    mi = mutual_info_regression(X_filtered, y)
    mi = pd.Series(mi)
    mi.index = names
    top_mi = mi.sort_values(ascending=False)[:num_features]
    #top_mi.plot.bar(figsize=(10, 4))
    #plt.xlabel('Features')
    #plt.ylabel('Mutual Information')
    #plt.title('Top 10 Features by Mutual Information')
    #plt.show()
    return top_mi.sort_values(ascending=False)

# %%
# importing dataset
with open('EJSLE_mnmdstdv_demoend.pkl', 'rb') as file:
    df = pickle.load(file)

file.close()

y_mean = df['LE_MEAN']
y_median = df['LE_MEDI']

# Selecting X variables by excluding unwanted columns
# exclusing STATE_NAME, ST_ABBREV, CITY_NAME, LE_MEAN, LE_MEDI
X = df.drop(['LE_MEAN', 'LE_MEDI'], axis=1)
X = X.drop(X.columns[:3], axis=1)

# excluding all demographic columns 
X= X.loc[:, :'P_PWDIS_D2_STDV']

# %%
num_features = 25
mean_features = Filter(X, y_mean, 0.5, "MEAN", num_features)

# %%
print(mean_features)
# Out:
# CANCER_MEAN        0.158891
# P_RESP_MEDI        0.137803
# P_CANCR_MEDI       0.131936
# D_LDPNT_2_MEDI     0.121485
# RESP_MEAN          0.117761
# RESP_MEDI          0.114336
# CANCER_MEDI        0.105610
# D_LDPNT_2_MEAN     0.100328
# D_RESP_2_MEDI      0.094584
# D_CANCR_2_MEDI     0.093205
# D_CANCR_2_MEAN     0.092600
# PM25_MEDI          0.090478
# PRE1960PCT_MEDI    0.080775
# PTSDF_MEAN         0.080169
# DSLPM_MEAN         0.078382
# D_UST_2_MEAN       0.077923
# PM25_MEAN          0.076158
# DSLPM_MEDI         0.074017
# D_RESP_2_MEAN      0.073509
# D_UST_2_MEDI       0.070674
# OZONE_MEDI         0.067405
# P_LDPNT_MEDI       0.064776
# OZONE_MEAN         0.063764
# P_RESP_D2_MEDI     0.061716
# D_UST_2_STDV       0.058236
# dtype: float64

# %%
# Convert the Pandas Series to a list of column names
selected_features = list(mean_features.index)[:num_features]

# Select only the rows of X that have column names in mean_features
X_select = X.loc[:, selected_features]

# %%
# define best_mse and type for feature selection
best_mse2 = 10000
best_type2 = ""

# %% [markdown]
# #### Linear Regression

# %%
targets = [y_mean, y_median]
target_names = ["Life expectancy mean", "Life expectancy median"]
colors = ['blue', 'red']
key_word = ["MEAN", "MEDI"]
for idx, target in enumerate(targets):
    mse_mean = []
    for i in range(1, 51):
        mean_features = Filter(X, y_mean, 0.5, key_word[idx], i)
        # Convert the Pandas Series to a list of column names
        selected_features = list(mean_features.index)[:i]

        # Select only the rows of X that have column names in mean_features
        X_select = X.loc[:, selected_features]
        
        # create copy of these to keep indexing correct in kfold cv below
        X_train_copy = X_select.copy()
        y_train_copy = target.copy()
        
        
        # perform k_folds for k = 3, 5, 10
        #k_folds = [3, 5, 10]
        k = [5]
        for k in k_folds:
            scores = [] 
            rmse_list = [] 
            mse_list = []
            lrmodel = LinearRegression()
            cv = KFold(n_splits=k, shuffle=True)
            for train_index, test_index in cv.split(X_train_copy):
                X_train, X_test = X_train_copy.iloc[train_index], X_train_copy.iloc[test_index]
                y_train_fold, y_test_fold = y_train_copy.iloc[train_index], y_train_copy.iloc[test_index] # use y_train_copy
                lrmodel.fit(X_train, y_train_fold)
                y_predict = lrmodel.predict(X_test)
                scores.append(r2_score(y_test_fold, y_predict))
                rmse_list.append(np.sqrt(mean_squared_error(y_test_fold, y_predict)))
                mse_list.append(mean_squared_error(y_test_fold, y_predict))
        mse_mean.append(np.mean(mse_list))
        print(f"Mean scores for num_features = {i} for target {target_names[idx]}:")
        print(f"\tR2: {np.mean(scores)}")
        print(f"\tRMSE: {np.mean(rmse_list)}")
        print(f"\tMSE: {np.mean(mse_list)}")
        print()
        if np.mean(mse_list) < best_mse2:
            best_mse2 = np.mean(mse_list)
            best_type2 = f"Linear regression for {i} features for the target {target_names[idx]}"

    plt.plot(range(1, 51), mse_mean, color=colors[idx], label=target_names[idx])
    
plt.xlabel("Number of Features")
plt.ylabel("Mean Squared Error (MSE)")
plt.xticks(range(0,51, 2))
plt.legend()
plt.show()
print(best_mse2, best_type2)
# Out:
# Mean scores for num_features = 1 for target Life expectancy mean:
# 	R2: 0.08486501432051634
# 	RMSE: 2.1329107147786583
# 	MSE: 4.5672118784892906
#
# Mean scores for num_features = 2 for target Life expectancy mean:
# 	R2: 0.055202879970739784
# 	RMSE: 2.1611803609904094
# 	MSE: 4.692752784890422
#
# Mean scores for num_features = 3 for target Life expectancy mean:
# 	R2: 0.0787209079703867
# 	RMSE: 2.143545559798927
# 	MSE: 4.629392288005361
#
# Mean scores for num_features = 4 for target Life expectancy mean:
# 	R2: 0.16978638500289156
# 	RMSE: 2.0309447522921227
# 	MSE: 4.133147011445487
#
# Mean scores for num_features = 5 for target Life expectancy mean:
# 	R2: 0.1768594609703423
# 	RMSE: 2.019601702126571
# 	MSE: 4.0825301882377705
#
# Mean scores for num_features = 6 for target Life expectancy mean:
# 	R2: 0.17886379167994457
# 	RMSE: 2.0171272192216065
# 	MSE: 4.074903091901213
#
# Mean scores for num_features = 7 for target Life expectancy mean:
# 	R2: 0.19055863912691898
# 	RMSE: 2.0052904900602764
# 	MSE: 4.034159431254347
#
# Mean scores for num_features = 8 for target Life expectancy mean:
# 	R2: 0.18497086310139904
# 	RMSE: 2.0125523367324143
# 	MSE: 4.06388962616748
#
# Mean scores for num_features = 9 for target Life expectancy mean:
# 	R2: 0.17670666441827224
# 	RMSE: 2.0195233228394605
# 	MSE: 4.0904463980704655
#
# Mean scores for num_features = 10 for target Life expectancy mean:
# 	R2: 0.2018321395349977
# 	RMSE: 1.991247132063722
# 	MSE: 3.9694638641322357
#
# Mean scores for num_features = 11 for target Life expectancy mean:
# 	R2: 0.2089552805908304
# 	RMSE: 1.9849024288757247
# 	MSE: 3.9610270885537893
#
# Mean scores for num_features = 12 for target Life expectancy mean:
# 	R2: 0.20307576652938505
# 	RMSE: 1.9941107515764642
# 	MSE: 3.99936195150256
#
# Mean scores for num_features = 13 for target Life expectancy mean:
# 	R2: 0.21865467858350937
# 	RMSE: 1.975993188201495
# 	MSE: 3.916943070951657
#
# Mean scores for num_features = 14 for target Life expectancy mean:
# 	R2: 0.27065180536599087
# 	RMSE: 1.9106221471756044
# 	MSE: 3.661103851910861
#
# Mean scores for num_features = 15 for target Life expectancy mean:
# 	R2: 0.24010591255737043
# 	RMSE: 1.9351604513799032
# 	MSE: 3.752048836297783
#
# Mean scores for num_features = 16 for target Life expectancy mean:
# 	R2: 0.2513893693273295
# 	RMSE: 1.925151568798368
# 	MSE: 3.7284049846574496
#
# Mean scores for num_features = 17 for target Life expectancy mean:
# 	R2: 0.2537635200623235
# 	RMSE: 1.9298922718844753
# 	MSE: 3.7290253910013127
#
# Mean scores for num_features = 18 for target Life expectancy mean:
# 	R2: 0.2610797699312621
# 	RMSE: 1.916960076236854
# 	MSE: 3.7198303462695876
#
# Mean scores for num_features = 19 for target Life expectancy mean:
# 	R2: 0.24722884186871327
# 	RMSE: 1.935679240381057
# 	MSE: 3.750169313697743
#
# Mean scores for num_features = 20 for target Life expectancy mean:
# 	R2: 0.25083638449129964
# 	RMSE: 1.9315545438533992
# 	MSE: 3.734375813712144
#
# Mean scores for num_features = 21 for target Life expectancy mean:
# 	R2: 0.25448368414368716
# 	RMSE: 1.9225633767009138
# 	MSE: 3.724700622015109
#
# Mean scores for num_features = 22 for target Life expectancy mean:
# 	R2: 0.26031410452992815
# 	RMSE: 1.9209827986090062
# 	MSE: 3.7092273486269995
#
# Mean scores for num_features = 23 for target Life expectancy mean:
# 	R2: 0.262923638832282
# 	RMSE: 1.917360073849387
# 	MSE: 3.683490169589722
#
# Mean scores for num_features = 24 for target Life expectancy mean:
# 	R2: 0.27729118496136457
# 	RMSE: 1.8961006001596576
# 	MSE: 3.6215620117983987
#
# Mean scores for num_features = 25 for target Life expectancy mean:
# 	R2: 0.2668534165189546
# 	RMSE: 1.9067167855624596
# 	MSE: 3.6396667755119694
#
# Mean scores for num_features = 26 for target Life expectancy mean:
# 	R2: 0.24796230253259005
# 	RMSE: 1.9361900757725987
# 	MSE: 3.768210563357715
#
# Mean scores for num_features = 27 for target Life expectancy mean:
# 	R2: 0.26139621192094414
# 	RMSE: 1.9177650701201128
# 	MSE: 3.6945950469733604
#
# Mean scores for num_features = 28 for target Life expectancy mean:
# 	R2: 0.27762886827145045
# 	RMSE: 1.8954230660895086
# 	MSE: 3.609768759653272
#
# Mean scores for num_features = 29 for target Life expectancy mean:
# 	R2: 0.2848813309907903
# 	RMSE: 1.890247318592833
# 	MSE: 3.6096237836746012
#
# Mean scores for num_features = 30 for target Life expectancy mean:
# 	R2: 0.268461505877565
# 	RMSE: 1.9073503343853708
# 	MSE: 3.6453851279062706
#
# Mean scores for num_features = 31 for target Life expectancy mean:
# 	R2: 0.23910383101996774
# 	RMSE: 1.940213301958078
# 	MSE: 3.7939596763670336
#
# Mean scores for num_features = 32 for target Life expectancy mean:
# 	R2: 0.2958726086857347
# 	RMSE: 1.8699908788468438
# 	MSE: 3.5046114726213737
#
# Mean scores for num_features = 33 for target Life expectancy mean:
# 	R2: 0.3071011518381076
# 	RMSE: 1.8600376854675809
# 	MSE: 3.464672348303368
#
# Mean scores for num_features = 34 for target Life expectancy mean:
# 	R2: 0.30060483596332865
# 	RMSE: 1.8708004708603743
# 	MSE: 3.508389340040343
#
# Mean scores for num_features = 35 for target Life expectancy mean:
# 	R2: 0.3453426256285604
# 	RMSE: 1.8067577826894514
# 	MSE: 3.268755557232894
#
# Mean scores for num_features = 36 for target Life expectancy mean:
# 	R2: 0.3332793398164968
# 	RMSE: 1.8203775627072578
# 	MSE: 3.3172041212261276
#
# Mean scores for num_features = 37 for target Life expectancy mean:
# 	R2: 0.3343161193979593
# 	RMSE: 1.8228345722708892
# 	MSE: 3.330901494447937
#
# Mean scores for num_features = 38 for target Life expectancy mean:
# 	R2: 0.338253884277348
# 	RMSE: 1.8186478845462422
# 	MSE: 3.313400278890966
#
# Mean scores for num_features = 39 for target Life expectancy mean:
# 	R2: 0.3352085955608681
# 	RMSE: 1.8205372468336551
# 	MSE: 3.3149451564811976
#
# Mean scores for num_features = 40 for target Life expectancy mean:
# 	R2: 0.33076291222304255
# 	RMSE: 1.8162372187314197
# 	MSE: 3.313410201286108
#
# Mean scores for num_features = 41 for target Life expectancy mean:
# 	R2: 0.3443827902431833
# 	RMSE: 1.8064304629787002
# 	MSE: 3.2714597808926014
#
# Mean scores for num_features = 42 for target Life expectancy mean:
# 	R2: 0.36783383585335744
# 	RMSE: 1.773068447483928
# 	MSE: 3.1495375224073365
#
# Mean scores for num_features = 43 for target Life expectancy mean:
# 	R2: 0.36495758256108835
# 	RMSE: 1.7756358933883818
# 	MSE: 3.158360227729157
#
# Mean scores for num_features = 44 for target Life expectancy mean:
# 	R2: 0.3645631792146525
# 	RMSE: 1.779315022575594
# 	MSE: 3.17090268108248
#
# Mean scores for num_features = 45 for target Life expectancy mean:
# 	R2: 0.35974227308465173
# 	RMSE: 1.783604167461958
# 	MSE: 3.184385197111491
#
# Mean scores for num_features = 46 for target Life expectancy mean:
# 	R2: 0.3603160207259175
# 	RMSE: 1.7832101127540496
# 	MSE: 3.18727081383964
#
# Mean scores for num_features = 47 for target Life expectancy mean:
# 	R2: 0.3540174603664987
# 	RMSE: 1.794310064722493
# 	MSE: 3.227719384177431
#
# Mean scores for num_features = 48 for target Life expectancy mean:
# 	R2: 0.36275609319568053
# 	RMSE: 1.7804650900236194
# 	MSE: 3.1812683313926504
#
# Mean scores for num_features = 49 for target Life expectancy mean:
# 	R2: 0.36781542950807555
# 	RMSE: 1.7759654827583362
# 	MSE: 3.1592273824704513
#
# Mean scores for num_features = 50 for target Life expectancy mean:
# 	R2: 0.3556288044077841
# 	RMSE: 1.7885054331437913
# 	MSE: 3.204532528239045
#
# Mean scores for num_features = 1 for target Life expectancy median:
# 	R2: 0.08291359483177532
# 	RMSE: 2.157453216201863
# 	MSE: 4.673283803043067
#
# Mean scores for num_features = 2 for target Life expectancy median:
# 	R2: 0.057863123523619976
# 	RMSE: 2.1805420651296403
# 	MSE: 4.780494444381351
#
# Mean scores for num_features = 3 for target Life expectancy median:
# 	R2: 0.04367406974505643
# 	RMSE: 2.1950891087025046
# 	MSE: 4.852672381860587
#
# Mean scores for num_features = 4 for target Life expectancy median:
# 	R2: 0.15824531045993817
# 	RMSE: 2.0598650218288266
# 	MSE: 4.2610392599746785
#
# Mean scores for num_features = 5 for target Life expectancy median:
# 	R2: 0.16973805337319292
# 	RMSE: 2.0497449905746343
# 	MSE: 4.217427904999893
#
# Mean scores for num_features = 6 for target Life expectancy median:
# 	R2: 0.20085811885011567
# 	RMSE: 2.0134638872759067
# 	MSE: 4.074636715980911
#
# Mean scores for num_features = 7 for target Life expectancy median:
# 	R2: 0.16763651226767812
# 	RMSE: 2.0482828487081823
# 	MSE: 4.207303034950142
#
# Mean scores for num_features = 8 for target Life expectancy median:
# 	R2: 0.1760253269170895
# 	RMSE: 2.0427295979151108
# 	MSE: 4.198633460063932
#
# Mean scores for num_features = 9 for target Life expectancy median:
# 	R2: 0.1707165319135519
# 	RMSE: 2.036566386096179
# 	MSE: 4.160593339744424
#
# Mean scores for num_features = 10 for target Life expectancy median:
# 	R2: 0.18422688062945558
# 	RMSE: 2.0281851034949065
# 	MSE: 4.120827341787916
#
# Mean scores for num_features = 11 for target Life expectancy median:
# 	R2: 0.1813246492257095
# 	RMSE: 2.028805231016107
# 	MSE: 4.152106758777608
#
# Mean scores for num_features = 12 for target Life expectancy median:
# 	R2: 0.17101576881218059
# 	RMSE: 2.043494793097748
# 	MSE: 4.205358638135994
#
# Mean scores for num_features = 13 for target Life expectancy median:
# 	R2: 0.2271354016973106
# 	RMSE: 1.9799033482921025
# 	MSE: 3.932139700388529
#
# Mean scores for num_features = 14 for target Life expectancy median:
# 	R2: 0.22522172954382622
# 	RMSE: 1.9693958462073085
# 	MSE: 3.8970879549252344
#
# Mean scores for num_features = 15 for target Life expectancy median:
# 	R2: 0.2545235453585962
# 	RMSE: 1.9425186110960275
# 	MSE: 3.781534669818028
#
# Mean scores for num_features = 16 for target Life expectancy median:
# 	R2: 0.2498140263423406
# 	RMSE: 1.94416504337281
# 	MSE: 3.785730183936264
#
# Mean scores for num_features = 17 for target Life expectancy median:
# 	R2: 0.25372383162625783
# 	RMSE: 1.9375816138454744
# 	MSE: 3.7620651425143796
#
# Mean scores for num_features = 18 for target Life expectancy median:
# 	R2: 0.25719665391172813
# 	RMSE: 1.939817682175865
# 	MSE: 3.7798773760823687
#
# Mean scores for num_features = 19 for target Life expectancy median:
# 	R2: 0.22793043382867406
# 	RMSE: 1.9719289537384639
# 	MSE: 3.9078533294801643
#
# Mean scores for num_features = 20 for target Life expectancy median:
# 	R2: 0.24433738586322923
# 	RMSE: 1.9530917511535555
# 	MSE: 3.835994414520298
#
# Mean scores for num_features = 21 for target Life expectancy median:
# 	R2: 0.24507371661791896
# 	RMSE: 1.9429943061714652
# 	MSE: 3.790755812049528
#
# Mean scores for num_features = 22 for target Life expectancy median:
# 	R2: 0.25623754051714015
# 	RMSE: 1.9357902365073674
# 	MSE: 3.7675347763548444
#
# Mean scores for num_features = 23 for target Life expectancy median:
# 	R2: 0.2829896190522305
# 	RMSE: 1.9070119394139706
# 	MSE: 3.672976385292172
#
# Mean scores for num_features = 24 for target Life expectancy median:
# 	R2: 0.2460697066142677
# 	RMSE: 1.947481932702442
# 	MSE: 3.801088623026056
#
# Mean scores for num_features = 25 for target Life expectancy median:
# 	R2: 0.27791253434210106
# 	RMSE: 1.9105725778035656
# 	MSE: 3.6610855237628632
#
# Mean scores for num_features = 26 for target Life expectancy median:
# 	R2: 0.24175316156671994
# 	RMSE: 1.9506641959979867
# 	MSE: 3.839449612062924
#
# Mean scores for num_features = 27 for target Life expectancy median:
# 	R2: 0.2828024329579766
# 	RMSE: 1.9065450076608434
# 	MSE: 3.6387968474389374
#
# Mean scores for num_features = 28 for target Life expectancy median:
# 	R2: 0.24866484233817715
# 	RMSE: 1.937319377650867
# 	MSE: 3.7768501268641357
#
# Mean scores for num_features = 29 for target Life expectancy median:
# 	R2: 0.2689127694834319
# 	RMSE: 1.9243453139787838
# 	MSE: 3.709410462095806
#
# Mean scores for num_features = 30 for target Life expectancy median:
# 	R2: 0.2747955259026914
# 	RMSE: 1.9151369174729447
# 	MSE: 3.6786632494228586
#
# Mean scores for num_features = 31 for target Life expectancy median:
# 	R2: 0.2997775077565122
# 	RMSE: 1.8817371693717564
# 	MSE: 3.5608684533515165
#
# Mean scores for num_features = 32 for target Life expectancy median:
# 	R2: 0.2921973802773191
# 	RMSE: 1.8850995506895554
# 	MSE: 3.5549058593551166
#
# Mean scores for num_features = 33 for target Life expectancy median:
# 	R2: 0.27022127253160777
# 	RMSE: 1.9149860895963804
# 	MSE: 3.679886666137979
#
# Mean scores for num_features = 34 for target Life expectancy median:
# 	R2: 0.2795795463033844
# 	RMSE: 1.904267503887708
# 	MSE: 3.633017705845475
#
# Mean scores for num_features = 35 for target Life expectancy median:
# 	R2: 0.29023522114752937
# 	RMSE: 1.8929526138337267
# 	MSE: 3.595261343404313
#
# Mean scores for num_features = 36 for target Life expectancy median:
# 	R2: 0.29668501657062296
# 	RMSE: 1.8875126370092385
# 	MSE: 3.56791026355861
#
# Mean scores for num_features = 37 for target Life expectancy median:
# 	R2: 0.3068015414462022
# 	RMSE: 1.8728825308669115
# 	MSE: 3.516641957865223
#
# Mean scores for num_features = 38 for target Life expectancy median:
# 	R2: 0.33708903407229496
# 	RMSE: 1.8326955545598103
# 	MSE: 3.3722678007897784
#
# Mean scores for num_features = 39 for target Life expectancy median:
# 	R2: 0.3499791009462142
# 	RMSE: 1.8161378295457353
# 	MSE: 3.3023926436322713
#
# Mean scores for num_features = 40 for target Life expectancy median:
# 	R2: 0.328533976091333
# 	RMSE: 1.8458023615478378
# 	MSE: 3.4199116421695392
#
# Mean scores for num_features = 41 for target Life expectancy median:
# 	R2: 0.34193103848731976
# 	RMSE: 1.8238238942107265
# 	MSE: 3.3459439613880924
#
# Mean scores for num_features = 42 for target Life expectancy median:
# 	R2: 0.3266931423208328
# 	RMSE: 1.8430793809883323
# 	MSE: 3.407828769219563
#
# Mean scores for num_features = 43 for target Life expectancy median:
# 	R2: 0.3419685772409934
# 	RMSE: 1.821633347024346
# 	MSE: 3.3358627478305634
#
# Mean scores for num_features = 44 for target Life expectancy median:
# 	R2: 0.3633803953920281
# 	RMSE: 1.7958874935764484
# 	MSE: 3.228230661520274
#
# Mean scores for num_features = 45 for target Life expectancy median:
# 	R2: 0.34850104943524884
# 	RMSE: 1.8112551403078136
# 	MSE: 3.2866356200016837
#
# Mean scores for num_features = 46 for target Life expectancy median:
# 	R2: 0.34814027928916175
# 	RMSE: 1.818230393784709
# 	MSE: 3.3099579218690445
#
# Mean scores for num_features = 47 for target Life expectancy median:
# 	R2: 0.3653124646328097
# 	RMSE: 1.7910063711650004
# 	MSE: 3.2179748469726634
#
# Mean scores for num_features = 48 for target Life expectancy median:
# 	R2: 0.36751681017514864
# 	RMSE: 1.7890763635834355
# 	MSE: 3.2109689091985105
#
# Mean scores for num_features = 49 for target Life expectancy median:
# 	R2: 0.3625877627623678
# 	RMSE: 1.7969328822916886
# 	MSE: 3.2452446084470643
#
# Mean scores for num_features = 50 for target Life expectancy median:
# 	R2: 0.34706587546757744
# 	RMSE: 1.817806769185139
# 	MSE: 3.3300933757843145
# 3.1495375224073365 Linear regression for 42 features for the target Life expectancy mean

# %% [markdown]
# #### Polynomial Regression

# %%
'''
for i in range(1, 26):
    mean_features = Filter(X, y_mean, 0.5, "MEAN", i)
    # Convert the Pandas Series to a list of column names
    selected_features = list(mean_features.index)[:i]
    print(selected_features)
    # Select only the rows of X that have column names in mean_features
    X_select = X.loc[:, selected_features]
    # perform k_folds for k = 3, 5, 10
    # split the dataset
    X_train, X_test, y_train, y_test = train_test_split(X_select, y_mean)
    X_train = X_train.values
    X_test = X_test.values
    y_train = y_train.values
    y_test = y_test.values

    # create a copy of y_train
    y_train_copy = y_train.copy()
    X_train_copy = X_train.copy()
    k_folds = [3, 5, 10]
    for k in k_folds:
        scores = [] 
        rmse_list = [] 
        mse_list = []
        cv = KFold(n_splits=5, shuffle=True)
        for train_index, test_index in cv.split(X_train_copy):
            X_train_fold, X_test_fold = X_train_copy[train_index], X_train_copy[test_index]
            y_train_fold, y_test_fold = y_train_copy[train_index], y_train_copy[test_index] # use y_train_copy

            model = make_pipeline(PolynomialFeatures(degree), LinearRegression())
            model.fit(X_train_fold, y_train_fold)

            y_predict = model.predict(X_test_fold)
            scores.append(r2_score(y_test_fold, y_predict))
            rmse_list.append(np.sqrt(mean_squared_error(y_test_fold, y_predict)))
            mse_list.append(mean_squared_error(y_test_fold, y_predict))

        print(f"Mean scores for k = {k} with {i} features:")
        print(f"\tR2: {np.mean(scores)}")
        print(f"\tRMSE: {np.mean(rmse_list)}")
        print(f"\tMSE: {np.mean(mse_list)}")
        print()
        if np.mean(mse_list) < best_mse2:
            best_mse2 = np.mean(mse_list)
            best_type2 = f"Linear regression for {i} features for the {target target_names[idx]}"
'''
# takes way too long and not greater mse values >> 1000
# Out:
# '\nfor i in range(1, 26):\n    mean_features = Filter(X, y_mean, 0.5, "MEAN", i)\n    # Convert the Pandas Series to a list of column names\n    selected_features = list(mean_features.index)[:i]\n    print(selected_features)\n    # Select only the rows of X that have column names in mean_features\n    X_select = X.loc[:, selected_features]\n    # perform k_folds for k = 3, 5, 10\n    # split the dataset\n    X_train, X_test, y_train, y_test = train_test_split(X_select, y_mean)\n    X_train = X_train.values\n    X_test = X_test.values\n    y_train = y_train.values\n    y_test = y_test.values\n\n    # create a copy of y_train\n    y_train_copy = y_train.copy()\n    X_train_copy = X_train.copy()\n    k_folds = [3, 5, 10]\n    for k in k_folds:\n        scores = [] \n        rmse_list = [] \n        mse_list = []\n        cv = KFold(n_splits=5, shuffle=True)\n        for train_index, test_index in cv.split(X_train_copy):\n            X_train_fold, X_test_fold = X_train_copy[train_index], X_train_copy[test_index]\n            y_train_fold, y_test_fold = y_train_copy[train_index], y_train_copy[test_index] # use y_train_copy\n\n            model = make_pipeline(PolynomialFeatures(degree), LinearRegression())\n            model.fit(X_train_fold, y_train_fold)\n\n            y_predict = model.predict(X_test_fold)\n            scores.append(r2_score(y_test_fold, y_predict))\n            rmse_list.append(np.sqrt(mean_squared_error(y_test_fold, y_predict)))\n            mse_list.append(mean_squared_error(y_test_fold, y_predict))\n\n        print(f"Mean scores for k = {k} with {i} features:")\n        print(f"\tR2: {np.mean(scores)}")\n        print(f"\tRMSE: {np.mean(rmse_list)}")\n        print(f"\tMSE: {np.mean(mse_list)}")\n        print()\n        if np.mean(mse_list) < best_mse2:\n            best_mse2 = np.mean(mse_list)\n            best_type2 = f"Linear regression for {i} features for the {target target_names[idx]}"\n'

# %% [markdown]
# #### Locally weighted Regressoin

# %%
def local_regression(xi, X, y, tau):
    m = X.shape[0]
    W = np.zeros((m,m))
    # fill in the weight matrix
    for i in range(m):
        xit = np.concatenate(([1], X[i, :]))  # add a 1 to the beginning of xit
        xi_ = np.concatenate(([1], xi[0, :]))  # add a 1 to the beginning of xi
        W[i, i] = np.exp(-np.dot((xi_ - xit), (xi_ - xit).T) / (2 * tau * tau))
    W += 1e-8 * np.identity(m)  # add a small constant to the diagonal to avoid zero weights
    W = W / np.sum(W, axis=0)  # normalize the weights
    lrmodel = LinearRegression()
    lrmodel.fit(X, y, sample_weight=W.diagonal())
    return lrmodel.predict(xi.reshape(1, -1))

targets = [y_mean, y_median]
target_names = ["Life expectancy mean", "Life expectancy median"]
colors = ['blue', 'red']
key_word = ["MEAN", "MEDI"]
num_features = [5, 10, 15, 20, 25]




width = 0.15
x_pos = np.arange(len(tau_list)) + len(num_features) * width / 2 # Modify x_pos array
colors = plt.cm.tab10(np.arange(len(num_features)))


# perform k_folds for k = 3, 5, 10
#k_folds = [3, 5, 10]
k_folds = [5]
# define a list of bandwidths to try
tau_list = [0.01, 0.05, 0.1, 0.5, 1, 5, 10]


for idx, target in enumerate(targets):
    fig, axs = plt.subplots(1, len(k_folds), figsize=(20, 5), sharey=True)
    #for i in num_features:
    for k in k_folds:     
        mse_tau = []

        #for k in k_folds:
        for tau in tau_list:
            mse_list = []
            
            #for tau in tau_list:
            for nf in num_features:
                mean_features = Filter(X, y_mean, 0.5, key_word[idx], i)
                # Convert the Pandas Series to a list of column names
                selected_features = list(mean_features.index)[:i]

                # Select only the rows of X that have column names in mean_features
                X_select = X.loc[:, selected_features]

                X_train_copy = X_select.values.copy()
                y_train = target.to_numpy().reshape(-1,1)
                kf = KFold(n_splits=k, shuffle=True)
                mse_list_k = []
                for train_index, test_index in kf.split(X_train_copy):
                    X_train_fold, X_test_fold = X_train_copy[train_index], X_train_copy[test_index]
                    y_train_fold, y_test_fold = y_train[train_index], y_train[test_index]

                    # Create a copy of y_train_fold
                    y_train_fold_copy = y_train_fold.copy()

                    y_pred_fold = np.zeros(len(X_test_fold))
                    for i in range(len(X_test_fold)):
                        y_pred_fold[i] = local_regression(X_test_fold[i].reshape(1,-1), X_train_fold, y_train_fold_copy, tau)

                    scores.append(r2_score(y_test_fold, y_pred_fold))
                    mse_list_k.append(mean_squared_error(y_test_fold, y_pred_fold))
                mse_list.append(np.mean(mse_list_k))
                print(f"Mean scores for k = {k} and tau = {tau}:")
                print(f"\tR2: {np.mean(scores)}")
                print(f"\tMSE: {np.mean(mse_list)}")
                print()
                print(mse_list)
                print()
                if np.mean(mse_list) < best_mse2:
                    best_mse2 = np.mean(mse_list)
                    best_type2 = f"Locally-weighted regression for {nf} features and tau = {tau} for the target {target_names[idx]}"
            mse_tau.append(mse_list)

         # Create a bar plot for each number of features
        width = 0.15
        for i, nf in enumerate(num_features):
            axs.bar(x_pos + i * width, [mse_tau[j][i] for j in range(len(tau_list))], width, label=f'{nf} features', color=colors[i])

        axs.set_xticks(x_pos + width * (len(num_features) - 1) / 2)
        axs.set_xticklabels(tau_list)
        axs.set_xlabel('Tau')
        axs.set_ylabel('Mean Squared Error')
        axs.set_title(f"MSE for {target_names[idx]} vs. Locally-Weighted Regression")
        axs.legend()
        ax.set_yscale("log")
        ax.set_ylim([1.5, 3.1])
        plt.show()
print(best_mse2, best_type2)
# Out:
# Mean scores for k = 5 and tau = 0.01:
# 	R2: 0.41145432411880806
# 	MSE: 4.2128280090436965
#
# [4.2128280090436965]
#
# Mean scores for k = 5 and tau = 0.01:
# 	R2: 0.41241380236321595
# 	MSE: 3.519462656209254
#
# [4.2128280090436965, 2.8260973033748114]
#
# Mean scores for k = 5 and tau = 0.01:
# 	R2: 0.41200800827453316
# 	MSE: 3.34250519554115
#
# [4.2128280090436965, 2.8260973033748114, 2.9885902742049413]
#
# Mean scores for k = 5 and tau = 0.01:
# 	R2: 0.41303958220165204
# 	MSE: 3.2053289123843296
#
# [4.2128280090436965, 2.8260973033748114, 2.9885902742049413, 2.7938000629138697]
#
# Mean scores for k = 5 and tau = 0.01:
# 	R2: 0.41324401052963916
# 	MSE: 3.142990839366739
#
# [4.2128280090436965, 2.8260973033748114, 2.9885902742049413, 2.7938000629138697, 2.8936385472963755]
#
# Mean scores for k = 5 and tau = 0.05:
# 	R2: 0.4143755800979942
# 	MSE: 2.7485580859426033
#
# [2.7485580859426033]
#
# Mean scores for k = 5 and tau = 0.05:
# 	R2: 0.41484795844914313
# 	MSE: 2.804146918113868
#
# [2.7485580859426033, 2.8597357502851324]
#
# Mean scores for k = 5 and tau = 0.05:
# 	R2: 0.4141112002881389
# 	MSE: 2.879071776880624
#
# [2.7485580859426033, 2.8597357502851324, 3.0289214944141363]
#
# Mean scores for k = 5 and tau = 0.05:
# 	R2: 0.41349604513539273
# 	MSE: 2.9172762194775825
#
# [2.7485580859426033, 2.8597357502851324, 3.0289214944141363, 3.031889547268458]
#
# Mean scores for k = 5 and tau = 0.05:
# 	R2: 0.4120951972590774
# 	MSE: 2.973105163119697
#
# [2.7485580859426033, 2.8597357502851324, 3.0289214944141363, 3.031889547268458, 3.1964209376881563]
#
# Mean scores for k = 5 and tau = 0.1:
# 	R2: 0.4126012336833164
# 	MSE: 2.8467358985935847
#
# [2.8467358985935847]
#
# Mean scores for k = 5 and tau = 0.1:
# 	R2: 0.4133306331844203
# 	MSE: 2.831985047731739
#
# [2.8467358985935847, 2.817234196869893]
#
# Mean scores for k = 5 and tau = 0.1:
# 	R2: 0.41374709045175956
# 	MSE: 2.8417333101497775
#
# [2.8467358985935847, 2.817234196869893, 2.861229834985854]
#
# Mean scores for k = 5 and tau = 0.1:
# 	R2: 0.41377007496370893
# 	MSE: 2.8597900618557417
#
# [2.8467358985935847, 2.817234196869893, 2.861229834985854, 2.913960316973634]
#
# Mean scores for k = 5 and tau = 0.1:
# 	R2: 0.4143323039732691
# 	MSE: 2.8535753261762955
#
# [2.8467358985935847, 2.817234196869893, 2.861229834985854, 2.913960316973634, 2.8287163834585116]
#
# Mean scores for k = 5 and tau = 0.5:
# 	R2: 0.414743139308964
# 	MSE: 2.842875897534694
#
# [2.842875897534694]
#
# Mean scores for k = 5 and tau = 0.5:
# 	R2: 0.41504798496180795
# 	MSE: 2.84874053008324
#
# [2.842875897534694, 2.854605162631786]
#
# Mean scores for k = 5 and tau = 0.5:
# 	R2: 0.4158894918395173
# 	MSE: 2.8166090876015475
#
# [2.842875897534694, 2.854605162631786, 2.752346202638164]
#
# Mean scores for k = 5 and tau = 0.5:
# 	R2: 0.415900328872255
# 	MSE: 2.841730910219127
#
# [2.842875897534694, 2.854605162631786, 2.752346202638164, 2.917096378071864]
#
# Mean scores for k = 5 and tau = 0.5:
# 	R2: 0.4164424954999208
# 	MSE: 2.8336420918377168
#
# [2.842875897534694, 2.854605162631786, 2.752346202638164, 2.917096378071864, 2.8012868183120765]
#
# Mean scores for k = 5 and tau = 1:
# 	R2: 0.41699120167245834
# 	MSE: 2.798977311479478
#
# [2.798977311479478]
#
# Mean scores for k = 5 and tau = 1:
# 	R2: 0.4164620495482909
# 	MSE: 2.913618426219051
#
# [2.798977311479478, 3.0282595409586244]
#
# Mean scores for k = 5 and tau = 1:
# 	R2: 0.4172737455010585
# 	MSE: 2.84758320372584
#
# [2.798977311479478, 3.0282595409586244, 2.7155127587394174]
#
# Mean scores for k = 5 and tau = 1:
# 	R2: 0.41704241234176764
# 	MSE: 2.8769828601187433
#
# [2.798977311479478, 3.0282595409586244, 2.7155127587394174, 2.9651818292974523]
#
# Mean scores for k = 5 and tau = 1:
# 	R2: 0.41754586257645293
# 	MSE: 2.8611159391783643
#
# [2.798977311479478, 3.0282595409586244, 2.7155127587394174, 2.9651818292974523, 2.7976482554168483]
#
# Mean scores for k = 5 and tau = 5:
# 	R2: 0.4177311028492328
# 	MSE: 2.8627989596172503
#
# [2.8627989596172503]
#
# Mean scores for k = 5 and tau = 5:
# 	R2: 0.4181586688829672
# 	MSE: 2.835950272449865
#
# [2.8627989596172503, 2.8091015852824794]
#
# Mean scores for k = 5 and tau = 5:
# 	R2: 0.4187352536297122
# 	MSE: 2.807915995834571
#
# [2.8627989596172503, 2.8091015852824794, 2.7518474426039843]
#
# Mean scores for k = 5 and tau = 5:
# 	R2: 0.418018035789085
# 	MSE: 2.878094132087966
#
# [2.8627989596172503, 2.8091015852824794, 2.7518474426039843, 3.08862854084815]
#
# Mean scores for k = 5 and tau = 5:
# 	R2: 0.41798529962576675
# 	MSE: 2.8857424245157697
#
# [2.8627989596172503, 2.8091015852824794, 2.7518474426039843, 3.08862854084815, 2.9163355942269846]
#
# Mean scores for k = 5 and tau = 10:
# 	R2: 0.4184382097834366
# 	MSE: 2.7856524455510514
#
# [2.7856524455510514]
#
# Mean scores for k = 5 and tau = 10:
# 	R2: 0.41815871734998605
# 	MSE: 2.8849129246503704
#
# [2.7856524455510514, 2.984173403749689]
#
# Mean scores for k = 5 and tau = 10:
# 	R2: 0.4171255510547283
# 	MSE: 2.971674594019069
#
# [2.7856524455510514, 2.984173403749689, 3.145197932756467]
#
# Mean scores for k = 5 and tau = 10:
# 	R2: 0.41742254353053543
# 	MSE: 2.9355020856066933
#
# [2.7856524455510514, 2.984173403749689, 3.145197932756467, 2.826984560369566]
#
# Mean scores for k = 5 and tau = 10:
# 	R2: 0.41755774405613966
# 	MSE: 2.9186098207128115
#
# [2.7856524455510514, 2.984173403749689, 3.145197932756467, 2.826984560369566, 2.8510407611372837]
# Mean scores for k = 5 and tau = 0.01:
# 	R2: 0.41325562636275615
# 	MSE: 4.199392816460022
#
# [4.199392816460022]
#
# Mean scores for k = 5 and tau = 0.01:
# 	R2: 0.4136372868648836
# 	MSE: 3.536409348651042
#
# [4.199392816460022, 2.8734258808420625]
#
# Mean scores for k = 5 and tau = 0.01:
# 	R2: 0.41389559980927215
# 	MSE: 3.322600917706962
#
# [4.199392816460022, 2.8734258808420625, 2.894984055818802]
#
# Mean scores for k = 5 and tau = 0.01:
# 	R2: 0.41385130397645326
# 	MSE: 3.2347193383721367
#
# [4.199392816460022, 2.8734258808420625, 2.894984055818802, 2.971074600367661]
#
# Mean scores for k = 5 and tau = 0.01:
# 	R2: 0.41405327628285976
# 	MSE: 3.1696035259130353
#
# [4.199392816460022, 2.8734258808420625, 2.894984055818802, 2.971074600367661, 2.9091402760766307]
#
# Mean scores for k = 5 and tau = 0.05:
# 	R2: 0.41403646586935605
# 	MSE: 2.9812931650322647
#
# [2.9812931650322647]
#
# Mean scores for k = 5 and tau = 0.05:
# 	R2: 0.41404573924539806
# 	MSE: 2.97567647411597
#
# [2.9812931650322647, 2.9700597831996753]
#
# Mean scores for k = 5 and tau = 0.05:
# 	R2: 0.41414697294723407
# 	MSE: 2.964364199275904
#
# [2.9812931650322647, 2.9700597831996753, 2.941739649595772]
#
# Mean scores for k = 5 and tau = 0.05:
# 	R2: 0.41433357449803104
# 	MSE: 2.9441939868571225
#
# [2.9812931650322647, 2.9700597831996753, 2.941739649595772, 2.883683349600778]
#
# Mean scores for k = 5 and tau = 0.05:
# 	R2: 0.41424719831110157
# 	MSE: 2.9542360640486245
#
# [2.9812931650322647, 2.9700597831996753, 2.941739649595772, 2.883683349600778, 2.994404372814631]
#
# Mean scores for k = 5 and tau = 0.1:
# 	R2: 0.41439094134528986
# 	MSE: 2.909443494224953
#
# [2.909443494224953]
#
# Mean scores for k = 5 and tau = 0.1:
# 	R2: 0.414558412464764
# 	MSE: 2.909117078673482
#
# [2.909443494224953, 2.9087906631220117]
#
# Mean scores for k = 5 and tau = 0.1:
# 	R2: 0.41476365009594385
# 	MSE: 2.903259082764452
#
# [2.909443494224953, 2.9087906631220117, 2.891543090946392]
#
# Mean scores for k = 5 and tau = 0.1:
# 	R2: 0.4148749889224587
# 	MSE: 2.909674168917198
#
# [2.909443494224953, 2.9087906631220117, 2.891543090946392, 2.928919427375435]
#
# Mean scores for k = 5 and tau = 0.1:
# 	R2: 0.4149372701683197
# 	MSE: 2.9171052068280097
#
# [2.909443494224953, 2.9087906631220117, 2.891543090946392, 2.928919427375435, 2.9468293584712573]
#
# Mean scores for k = 5 and tau = 0.5:
# 	R2: 0.4141381658674112
# 	MSE: 3.246115682093471
#
# [3.246115682093471]
#
# Mean scores for k = 5 and tau = 0.5:
# 	R2: 0.4140800907256137
# 	MSE: 3.1221244896118736
#
# [3.246115682093471, 2.998133297130276]
#
# Mean scores for k = 5 and tau = 0.5:
# 	R2: 0.41415344931898695
# 	MSE: 3.0608890959612967
#
# [3.246115682093471, 2.998133297130276, 2.938418308660142]
#
# Mean scores for k = 5 and tau = 0.5:
# 	R2: 0.4140689850448309
# 	MSE: 3.048295075031182
#
# [3.246115682093471, 2.998133297130276, 2.938418308660142, 3.0105130122408394]
#
# Mean scores for k = 5 and tau = 0.5:
# 	R2: 0.41408037564957334
# 	MSE: 3.023659116311157
#
# [3.246115682093471, 2.998133297130276, 2.938418308660142, 3.0105130122408394, 2.925115281431056]
#
# Mean scores for k = 5 and tau = 1:
# 	R2: 0.41433366380603204
# 	MSE: 2.873682982453424
#
# [2.873682982453424]
#
# Mean scores for k = 5 and tau = 1:
# 	R2: 0.41446611592279325
# 	MSE: 2.9018869702381234
#
# [2.873682982453424, 2.9300909580228227]
#
# Mean scores for k = 5 and tau = 1:
# 	R2: 0.4145563311118509
# 	MSE: 2.908180607454094
#
# [2.873682982453424, 2.9300909580228227, 2.920767881886035]
#
# Mean scores for k = 5 and tau = 1:
# 	R2: 0.4146802790697169
# 	MSE: 2.9100234847409197
#
# [2.873682982453424, 2.9300909580228227, 2.920767881886035, 2.9155521166013973]
#
# Mean scores for k = 5 and tau = 1:
# 	R2: 0.4147704354676268
# 	MSE: 2.9131886980843786
#
# [2.873682982453424, 2.9300909580228227, 2.920767881886035, 2.9155521166013973, 2.9258495514582146]
#
# Mean scores for k = 5 and tau = 5:
# 	R2: 0.4149284195290963
# 	MSE: 2.910589244026956
#
# [2.910589244026956]
#
# Mean scores for k = 5 and tau = 5:
# 	R2: 0.41475021382161537
# 	MSE: 2.9775610157640946
#
# [2.910589244026956, 3.0445327875012334]
#
# Mean scores for k = 5 and tau = 5:
# 	R2: 0.4146335305062745
# 	MSE: 2.992277103239573
#
# [2.910589244026956, 3.0445327875012334, 3.0217092781905306]
#
# Mean scores for k = 5 and tau = 5:
# 	R2: 0.41463956752558995
# 	MSE: 2.9813285222524466
#
# [2.910589244026956, 3.0445327875012334, 3.0217092781905306, 2.948482779291067]
#
# Mean scores for k = 5 and tau = 5:
# 	R2: 0.4146838815495144
# 	MSE: 2.972758325000118
#
# [2.910589244026956, 3.0445327875012334, 3.0217092781905306, 2.948482779291067, 2.9384775359908035]
#
# Mean scores for k = 5 and tau = 10:
# 	R2: 0.41444272112657027
# 	MSE: 3.0571081830796025
#
# [3.0571081830796025]
#
# Mean scores for k = 5 and tau = 10:
# 	R2: 0.41447615895810025
# 	MSE: 2.984872150173505
#
# [3.0571081830796025, 2.912636117267408]
#
# Mean scores for k = 5 and tau = 10:
# 	R2: 0.41464178896136283
# 	MSE: 2.9535333839898548
#
# [3.0571081830796025, 2.912636117267408, 2.8908558516225535]
#
# Mean scores for k = 5 and tau = 10:
# 	R2: 0.41458422373719506
# 	MSE: 2.958905731659013
#
# [3.0571081830796025, 2.912636117267408, 2.8908558516225535, 2.975022774666489]
#
# Mean scores for k = 5 and tau = 10:
# 	R2: 0.41471412661199614
# 	MSE: 2.949383034802085
#
# [3.0571081830796025, 2.912636117267408, 2.8908558516225535, 2.975022774666489, 2.9112922473743725]
# 2.7485580859426033 Locally-weighted regression for 5 features and tau = 0.05 for the target Life expectancy mean

# %% [markdown]
# #### KNN

# %%
targets = [y_mean, y_median]
target_names = ["Life expectancy mean", "Life expectancy median"]
colors = ['blue', 'red']
key_word = ["MEAN", "MEDI"]

num_features = [5, 10, 15, 20, 25]
neighbors = list(range(1, 26))

for idx, target in enumerate(targets):
    fig, axs = plt.subplots(1, 1, figsize=(10, 5))
    for i in num_features:
        mean_features = Filter(X, y_mean, 0.5, key_word[idx], i)
        # Convert the Pandas Series to a list of column names
        selected_features = list(mean_features.index)[:i]

        # Select only the rows of X that have column names in mean_features
        X_select = X.loc[:, selected_features]
        
        # create copy of these to keep indexing correct in kfold cv below
        X_train_norm = normalization(X_select.values)
        y_train_norm = normalization(target)

        mse_list = []
        for n in neighbors:
            knn_model = KNeighborsRegressor(n_neighbors=n)
            cv = KFold(n_splits=5, shuffle=True)
            mse_list_k = []
            for train_index, test_index in cv.split(X_train_norm):
                X_train_fold, X_test_fold = X_train_norm[train_index], X_train_norm[test_index]
                y_train_fold, y_test_fold = y_train_norm.iloc[train_index], y_train_norm.iloc[test_index]
                knn_model.fit(X_train_fold, y_train_fold)
                y_predict_norm = knn_model.predict(X_test_fold)
                mse_list_k.append(mean_squared_error(y_test_fold, y_predict_norm))
            mse_list.append(np.mean(mse_list_k))
            if np.mean(mse_list_k) < best_mse2:
                best_mse2 = np.mean(mse_list_k)
                best_type2 = f"KNN for {i} neighbors for the target {target_names[idx]}"

        axs.plot(neighbors, mse_list, label=f'{i} features')
        axs.set_title(f"MSE for {target_names[idx]} vs. K-Nearest Neighbor")
        axs.set_xlabel("Number of Neighbors")
        axs.set_ylabel("MSE")
        axs.legend()
    plt.show()
print(best_mse2, best_type2)
# Out:
# 0.4792243823716473 SVR for 25 features and kernel = rbf for the target Life expectancy median

# %% [markdown]
# #### SVR

# %%
# Define the targets, target names, number of features, k folds, and kernels
targets = [y_mean, y_median]
target_names = ["Life expectancy mean", "Life expectancy median"]
num_features = [5, 10, 15, 20, 25]
k_folds = [5]
kernels = ['linear', 'poly', 'rbf']
key_word = ["MEAN", "MEDI"]
width = 0.15
x_pos = np.arange(len(kernels)) + len(num_features) * width / 2 # Modify x_pos array
colors = plt.cm.tab10(np.arange(len(num_features)))
# Loop over the targets and plot the MSE for each kernel and number of features
for idx, target in enumerate(targets):
    fig, axs = plt.subplots(1, len(k_folds), figsize=(20, 5), sharey=True)
    for k_idx, k in enumerate(k_folds):
        mse_kernel = []
        for ker in kernels:
            mse_list = []
            
            for i in num_features:
                mean_features = Filter(X, y_mean, 0.5, key_word[idx], i)
                selected_features = list(mean_features.index)[:i]
                X_select = X.loc[:, selected_features]
                X_train_norm = normalization(X_select.values)
                y_train_norm = normalization(target)
                svr_model = SVR(kernel=ker)
                cv = KFold(n_splits=k, shuffle=True)
                mse_list_k = []
                for train_index, test_index in cv.split(X_train_norm):
                    X_train_fold, X_test_fold = X_train_norm[train_index], X_train_norm[test_index]
                    y_train_fold, y_test_fold = y_train_norm.iloc[train_index], y_train_norm.iloc[test_index]
                    svr_model.fit(X_train_fold, y_train_fold)
                    y_predict_norm = svr_model.predict(X_test_fold)
                    mse_list_k.append(mean_squared_error(y_test_fold, y_predict_norm))
                mse_list.append(np.mean(mse_list_k))
                if np.mean(mse_list_k) < best_mse2:
                    best_mse2 = np.mean(mse_list_k)
                    best_type2 = f"SVR for {i} features and kernel = {ker} for the target {target_names[idx]}"
            mse_kernel.append(mse_list)

        # Create a bar plot for each number of features
        width = 0.15
        for i, nf in enumerate(num_features):
            axs.bar(x_pos + i * width, [mse_kernel[j][i] for j in range(len(kernels))], width, label=f'{nf} features', color=colors[i])

        axs.set_xticks(x_pos + width * (len(num_features) - 1) / 2)
        axs.set_xticklabels(kernels)
        axs.set_xlabel('Kernel')
        axs.set_ylabel('Mean Squared Error')
        axs.set_title(f"MSE for {target_names[idx]} vs. Support Vector Regression")
        axs.legend()
        ax.set_yscale("log")

        plt.show()
print(best_mse2, best_type2)
# Out:
# 0.4708360712566838 SVR for 25 features and kernel = rbf for the target Life expectancy mean

# %%
print("For feature selection, the lowest MSE value with kfold cv of k = 5 is:")
print(f"\t {best_type2}")
print(f"\t MSE = {best_mse2}")
best_type_overall = ""
if (best_mse < best_mse2):
      best_mse_overall = best_mse
      best_type_overall = best_type
      method = "PCA"
else:
      best_mse_overall = best_mse2
      best_type_overall = best_type2
      method = "filter"
print(f"The best overall MSE from both PCA and Feature selection is with the method {method}")
print(f"\t {best_type_overall}")
print(f"\t MSE = {best_mse_overall}")
# Out:
# For feature selection, the lowest MSE value with kfold cv of k = 5 is:
# 	 SVR for 25 features and kernel = rbf for the target Life expectancy mean
# 	 MSE = 0.4708360712566838
# The best overall MSE from both PCA and Feature selection is with the method filter
# 	 SVR for 25 features and kernel = rbf for the target Life expectancy mean
# 	 MSE = 0.4708360712566838
